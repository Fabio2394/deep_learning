# %% [markdown]
# It is highly recommended to use a powerful **GPU**, you can use it for free uploading this notebook to [Google Colab](https://colab.research.google.com/notebooks/intro.ipynb).
# <table align="center">
#  <td align="center"><a target="_blank" href="https://colab.research.google.com/github/ezponda/intro_deep_learning/blob/main/class/Fundamentals/NN_Fundamentals.ipynb">
#         <img src="https://colab.research.google.com/img/colab_favicon_256px.png"  width="50" height="50" style="padding-bottom:5px;" />Run in Google Colab</a></td>
#   <td align="center"><a target="_blank" href="https://github.com/ezponda/intro_deep_learning/blob/main/class/Fundamentals/NN_Fundamentals.ipynb">
#         <img src="https://github.githubassets.com/images/modules/logos_page/GitHub-Mark.png"  width="50" height="50" style="padding-bottom:5px;" />View Source on GitHub</a></td>
# </table>

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

import numpy as np
import sklearn
import sklearn.datasets
import sklearn.linear_model
import matplotlib.pyplot as plt
# %matplotlib inline

tf.random.set_seed(0)

# %%
def plot_decision_boundary(model, X, y):
    # Set min and max values and give it some padding
    x_min, x_max = X[:, 0].min() - 1, X[:, 0].max() + 1
    y_min, y_max = X[:,1].min() - 1, X[:,1].max() + 1
    h = 0.05
    # Generate a grid of points with distance h between them
    xx, yy = np.meshgrid(np.arange(x_min, x_max, h), np.arange(y_min, y_max, h))
    # Predict the function value for the whole grid
    Z = model(np.c_[xx.ravel(), yy.ravel()])
    Z = Z.reshape(xx.shape)
    # Plot the contour and training examples
    plt.contourf(xx, yy, Z, cmap=plt.cm.Spectral)
    plt.ylabel('x2')
    plt.xlabel('x1')
    plt.scatter(X[:,0], X[:,1], c=y.ravel(), cmap=plt.cm.Spectral)

def load_planar_dataset(m, sigma=0.2):
    N = int(m/2) # number of points per class
    D = 2 # dimensionality
    X = np.zeros((m,D)) # data matrix where each row is a single example
    Y = np.zeros((m,1), dtype='uint8') # labels vector (0 for red, 1 for blue)
    a = 4 # maximum ray of the flower

    for j in range(2):
        ix = range(N*j,N*(j+1))
        t = np.linspace(j*3.12,(j+1)*3.12,N) + np.random.randn(N)*sigma # theta
        r = a*np.sin(4*t) + np.random.randn(N)*sigma # radius
        X[ix] = np.c_[r*np.sin(t), r*np.cos(t)]
        Y[ix] = j

    ## premuting ouput
    p = np.random.permutation(m)
    X = X[p,:]
    Y = Y[p,:]

    return X, Y.ravel()

def draw_neural_net(left, right, bottom, top, layer_sizes):
    '''
    From https://gist.github.com/craffel/2d727968c3aaebd10359#file-draw_neural_net-py
    Draw a neural network cartoon using matplotilb.

    :usage:
        >>> fig = plt.figure(figsize=(12, 12))
        >>> draw_neural_net(fig.gca(), .1, .9, .1, .9, [4, 7, 2])

    :parameters:
        - ax : matplotlib.axes.AxesSubplot
            The axes on which to plot the cartoon (get e.g. by plt.gca())
        - left : float
            The center of the leftmost node(s) will be placed here
        - right : float
            The center of the rightmost node(s) will be placed here
        - bottom : float
            The center of the bottommost node(s) will be placed here
        - top : float
            The center of the topmost node(s) will be placed here
        - layer_sizes : list of int
            List of layer sizes, including input and output dimensionality
    '''
    fig = plt.figure(figsize=(3, 3))
    ax = fig.gca()
    ax.axis('off')

    n_layers = len(layer_sizes)
    v_spacing = (top - bottom)/float(max(layer_sizes))
    h_spacing = (right - left)/float(len(layer_sizes) - 1)
    # Nodes
    for n, layer_size in enumerate(layer_sizes):
        layer_top = v_spacing*(layer_size - 1)/2. + (top + bottom)/2.
        for m in range(layer_size):
            circle = plt.Circle((n*h_spacing + left, layer_top - m*v_spacing), v_spacing/4.,
                                color='w', ec='k', zorder=4)
            ax.add_artist(circle)
    # Edges
    for n, (layer_size_a, layer_size_b) in enumerate(zip(layer_sizes[:-1], layer_sizes[1:])):
        layer_top_a = v_spacing*(layer_size_a - 1)/2. + (top + bottom)/2.
        layer_top_b = v_spacing*(layer_size_b - 1)/2. + (top + bottom)/2.
        for m in range(layer_size_a):
            for o in range(layer_size_b):
                line = plt.Line2D([n*h_spacing + left, (n + 1)*h_spacing + left],
                                  [layer_top_a - m*v_spacing, layer_top_b - o*v_spacing], c='k')
                ax.add_artist(line)

# %% [markdown]
# ## Dataset
#
# We have a binary classification dataset. The target `y` has two possible values, {0,1} and the input vector `x` has two dimensions.

# %%
N = 5000
X, y = load_planar_dataset(N, 0.2)

# %% [markdown]
# Visualize the dataset using matplotlib. The data looks like a "flower" with some red (label y=0) and some blue (y=1) points. Your goal is to build a model to fit this data.

# %%
# Visualize the data:
plt.scatter(X[:,0], X[:,1], c=y.ravel(), s=40, cmap=plt.cm.Spectral);

# %%
# train test split
from sklearn.model_selection import train_test_split

(X_train, X_test, y_train, y_test) = train_test_split(
    X,
    y,
    test_size=0.2,
)

# %%
print('X shape:{0}, y shape:{1}'.format(X.shape, y.shape))
print('X_train shape:{0}, y_train shape:{1}'.format(X_train.shape,
                                                    y_train.shape))
print('X_test shape:{0}, y_test shape:{1}'.format(X_test.shape, y_test.shape))
# Out:
# X shape:(5000, 2), y shape:(5000,)
# X_train shape:(4000, 2), y_train shape:(4000,)
# X_test shape:(1000, 2), y_test shape:(1000,)

# %%
## X first example
X[0,:]
# Out:
# array([2.71358683, 1.70664011])

# %%
## Y firsts examples
y[:8]
# Out:
# array([1, 0, 1, 0, 0, 0, 0, 0], dtype=uint8)

# %% [markdown]
# ## First NN in Keras
#
# ### Logistic regression
#
# Fully connected layers are defined using the [Dense](https://www.tensorflow.org/api_docs/python/tf/keras/layers/Dense) class. We can specify the number of neurons as the first argument, and specify the activation function using the activation argument.
#
# ```python
# tf.keras.layers.Dense(
#     units, activation=None
# )
#
# ```
#
# - **units**: Number of neurons in the layer.
# - **activation**: Activation function to use, default function is `linear`, you can also use `sigmoid` for sigmoid activation or [other alternatives](https://www.tensorflow.org/api_docs/python/tf/keras/activations)
#
# For defining the input layer you can use `keras.Input(shape=(input_dimension,))` or define your input dimension in the first hidden layer.
#
# ```python
# layers.Dense(4, activation="sigmoid", input_shape=(input_dimension,))
#
# ```
#
# Build a network without hidden layer

# %%
draw_neural_net(.1, .9, .1, .9, [2, 1])

# %%
model = keras.Sequential()
# The dimension of the input is 2 (planar data)
# we have only one output layer with 1 neuron
model.add(keras.layers.Dense(1, input_shape=(2, ), activation='sigmoid'))
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 1)              │             3 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 3 (12.00 B)
#  Trainable params: 3 (12.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
from tensorflow.keras.utils import plot_model
plot_model(model, show_shapes=True)

# %% [markdown]
# #### Compile
# Now we need to specify the loss function, the metrics and the optimizer. It is done using compile function in Keras.

# %%
model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)

# %% [markdown]
# #### Training model
# This is similar to a sklearn model.

# %%
model.fit(X_train, y_train, epochs=10,
          validation_split=0.2, batch_size=32)
# Out:
# Epoch 1/10
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.5716 - loss: 0.8451 - val_accuracy: 0.5650 - val_loss: 0.8453
# Epoch 2/10
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.5604 - loss: 0.7995 - val_accuracy: 0.5525 - val_loss: 0.7999
# Epoch 3/10
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.5524 - loss: 0.7608 - val_accuracy: 0.5412 - val_loss: 0.7622
# Epoch 4/10
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.5410 - loss: 0.7294 - val_accuracy: 0.5312 - val_loss: 0.7323
# Epoch 5/10
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5279 - loss: 0.7051 - val_accuracy: 0.5213 - val_loss: 0.7098
# Epoch 6/10
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.5160 - loss: 0.6874 - val_accuracy: 0.5025 - val_loss: 0.6937
# Epoch 7/10
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5073 - loss: 0.6754 - val_accuracy: 0.4925 - val_loss: 0.6830
# Epoch 8/10
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4970 - loss: 0.6677 - val_accuracy: 0.4787 - val_loss: 0.6761
# Epoch 9/10
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4858 - loss: 0.6632 - val_accuracy: 0.4613 - val_loss: 0.6719
# Epoch 10/10
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4784 - loss: 0.6608 - val_accuracy: 0.4512 - val_loss: 0.6694

# %% [markdown]
# #### Making predictions

# %%
results = model.evaluate(X_test, y_test, verbose=0)
print('Test Loss: {}'.format(results[0]))
print('Test Accuracy: {}'.format(results[1]))
# Out:
# Test Loss: 0.6600855588912964
# Test Accuracy: 0.4749999940395355

# %%
y_pred = model.predict(X_test)
y_pred[:3], y_test[:3]
# Out:
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# (array([[0.6004359 ],
#         [0.36737272],
#         [0.24869877]], dtype=float32),
#  array([0, 1, 0], dtype=uint8))

# %%
plot_decision_boundary(lambda x: (
    model.predict(x) > 0.5).astype("int32"), X_test, y_test)
plt.title("Basic NN");
# Out:
# 1288/1288 ━━━━━━━━━━━━━━━━━━━━ 1s 949us/step

# %% [markdown]
# ### One hidden layer NN
#
# - One **input with 2 features (input_shape)**
# - **One hidden dense layer**,  with **3 neurons** and implemented with  **sigmoid activating function**
# - **One Output** (sigmoid output activation function)
#
# We can create layers incrementally with the method `add()`:

# %%
draw_neural_net(.1, .9, .1, .9, [2, 3, 1])

# %%
model = keras.Sequential()

## hidden layer with 3 neurons and sigmoid activation
## The first layer need to have the input_shape
model.add(layers.Dense(3, input_shape=(2,), activation='sigmoid'))

# output layer
model.add(layers.Dense(1, activation='sigmoid'))

## model summary
model.summary()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_1 (Dense)                 │ (None, 3)              │             9 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │             4 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 13 (52.00 B)
#  Trainable params: 13 (52.00 B)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# You can also define the model with a list of layers
# ```python
# model = keras.Sequential([
#     keras.Input(shape=(2, )),
#     layers.Dense(3, activation='sigmoid', name='layer1'),
#     layers.Dense(1, activation='sigmoid', name='layer3')
# ])
# ````

# %%
plot_model(model, show_shapes=True)

# %%
## compiling and training
model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)
model.fit(X_train, y_train, epochs=25, validation_split=0.2, batch_size=32)
# Out:
# Epoch 1/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.4914 - loss: 0.8626 - val_accuracy: 0.4975 - val_loss: 0.8102
# Epoch 2/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4914 - loss: 0.7999 - val_accuracy: 0.4975 - val_loss: 0.7639
# Epoch 3/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4916 - loss: 0.7561 - val_accuracy: 0.5063 - val_loss: 0.7329
# Epoch 4/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5277 - loss: 0.7267 - val_accuracy: 0.5587 - val_loss: 0.7122
# Epoch 5/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5570 - loss: 0.7067 - val_accuracy: 0.5525 - val_loss: 0.6976
# Epoch 6/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5605 - loss: 0.6926 - val_accuracy: 0.5275 - val_loss: 0.6872
# Epoch 7/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5124 - loss: 0.6825 - val_accuracy: 0.5125 - val_loss: 0.6800
# Epoch 8/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5344 - loss: 0.6752 - val_accuracy: 0.5512 - val_loss: 0.6748
# Epoch 9/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5907 - loss: 0.6699 - val_accuracy: 0.6075 - val_loss: 0.6709
# Epoch 10/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6168 - loss: 0.6657 - val_accuracy: 0.6187 - val_loss: 0.6678
# Epoch 11/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6319 - loss: 0.6623 - val_accuracy: 0.6250 - val_loss: 0.6651
# Epoch 12/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6389 - loss: 0.6593 - val_accuracy: 0.6300 - val_loss: 0.6627
# Epoch 13/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6480 - loss: 0.6567 - val_accuracy: 0.6325 - val_loss: 0.6604
# Epoch 14/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6499 - loss: 0.6542 - val_accuracy: 0.6375 - val_loss: 0.6582
# Epoch 15/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6525 - loss: 0.6519 - val_accuracy: 0.6400 - val_loss: 0.6561
# Epoch 16/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6528 - loss: 0.6497 - val_accuracy: 0.6388 - val_loss: 0.6541
# Epoch 17/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6534 - loss: 0.6476 - val_accuracy: 0.6388 - val_loss: 0.6520
# Epoch 18/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6533 - loss: 0.6455 - val_accuracy: 0.6363 - val_loss: 0.6499
# Epoch 19/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6539 - loss: 0.6435 - val_accuracy: 0.6363 - val_loss: 0.6478
# Epoch 20/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6545 - loss: 0.6414 - val_accuracy: 0.6350 - val_loss: 0.6456
# Epoch 21/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6524 - loss: 0.6393 - val_accuracy: 0.6338 - val_loss: 0.6432
# Epoch 22/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6530 - loss: 0.6370 - val_accuracy: 0.6338 - val_loss: 0.6406
# Epoch 23/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6556 - loss: 0.6346 - val_accuracy: 0.6375 - val_loss: 0.6376
# Epoch 24/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6557 - loss: 0.6318 - val_accuracy: 0.6400 - val_loss: 0.6339
# Epoch 25/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6563 - loss: 0.6284 - val_accuracy: 0.6425 - val_loss: 0.6293

# %%
results = model.evaluate(X_test, y_test, verbose=0)
print('Test Loss: {}'.format(results[0]))
print('Test Accuracy: {}'.format(results[1]))
# Out:
# Test Loss: 0.6270325183868408
# Test Accuracy: 0.6489999890327454

# %%
plot_decision_boundary(lambda x: (
    model.predict(x) > 0.5).astype("int32"), X_test, y_test)
plt.title("1 Hidden layer NN");
# Out:
# 1288/1288 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step

# %% [markdown]
# ### Question 1:
# ####  What happens if we change the activation function of the first hidden  layer to `'linear'`?

# %%
model = keras.Sequential()
## The first layer need to have the input_shape
## change the activation function
model.add(layers.Dense(3, input_shape=(2,), activation='linear'))
# output layer
model.add(layers.Dense(1, activation='sigmoid'))

# %%
## compiling and training
model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)
model.fit(X_train, y_train, epochs=25, validation_split=0.2, batch_size=32)
# Out:
# Epoch 1/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.6242 - loss: 0.6732 - val_accuracy: 0.4863 - val_loss: 0.6688
# Epoch 2/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4791 - loss: 0.6595 - val_accuracy: 0.4462 - val_loss: 0.6667
# Epoch 3/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4651 - loss: 0.6589 - val_accuracy: 0.4450 - val_loss: 0.6663
# Epoch 4/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4654 - loss: 0.6588 - val_accuracy: 0.4450 - val_loss: 0.6662
# Epoch 5/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4661 - loss: 0.6588 - val_accuracy: 0.4450 - val_loss: 0.6662
# Epoch 6/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4663 - loss: 0.6588 - val_accuracy: 0.4450 - val_loss: 0.6662
# Epoch 7/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4663 - loss: 0.6588 - val_accuracy: 0.4450 - val_loss: 0.6662
# Epoch 8/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4663 - loss: 0.6588 - val_accuracy: 0.4450 - val_loss: 0.6662
# Epoch 9/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4663 - loss: 0.6588 - val_accuracy: 0.4450 - val_loss: 0.6662
# Epoch 10/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4663 - loss: 0.6588 - val_accuracy: 0.4450 - val_loss: 0.6662
# Epoch 11/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4663 - loss: 0.6588 - val_accuracy: 0.4450 - val_loss: 0.6662
# Epoch 12/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4663 - loss: 0.6588 - val_accuracy: 0.4450 - val_loss: 0.6662
# Epoch 13/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4663 - loss: 0.6588 - val_accuracy: 0.4450 - val_loss: 0.6662
# Epoch 14/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4663 - loss: 0.6588 - val_accuracy: 0.4450 - val_loss: 0.6662
# Epoch 15/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4663 - loss: 0.6588 - val_accuracy: 0.4450 - val_loss: 0.6662
# Epoch 16/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4663 - loss: 0.6588 - val_accuracy: 0.4450 - val_loss: 0.6662
# Epoch 17/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4663 - loss: 0.6588 - val_accuracy: 0.4450 - val_loss: 0.6662
# Epoch 18/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4663 - loss: 0.6588 - val_accuracy: 0.4450 - val_loss: 0.6662
# Epoch 19/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4663 - loss: 0.6588 - val_accuracy: 0.4450 - val_loss: 0.6662
# Epoch 20/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4663 - loss: 0.6588 - val_accuracy: 0.4450 - val_loss: 0.6662
# Epoch 21/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4663 - loss: 0.6588 - val_accuracy: 0.4450 - val_loss: 0.6662
# Epoch 22/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4663 - loss: 0.6588 - val_accuracy: 0.4450 - val_loss: 0.6662
# Epoch 23/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4663 - loss: 0.6588 - val_accuracy: 0.4450 - val_loss: 0.6662
# Epoch 24/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4663 - loss: 0.6588 - val_accuracy: 0.4450 - val_loss: 0.6662
# Epoch 25/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4663 - loss: 0.6588 - val_accuracy: 0.4450 - val_loss: 0.6662

# %%
results = model.evaluate(X_test, y_test, verbose=0)
print('Test Loss: {}'.format(results[0]))
print('Test Accuracy: {}'.format(results[1]))
plot_decision_boundary(lambda x: (
    model.predict(x) > 0.5).astype("int32"), X_test, y_test)
plt.title("1 Hidden layer NN, linear activation");
# Out:
# Test Loss: 0.6583550572395325
# Test Accuracy: 0.4659999907016754
# 1288/1288 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step

# %% [markdown]
# ### Question 2:
# ####  What happens if we add more neurons to the first hidden layer ?

# %%
draw_neural_net(.1, .9, .1, .9, [2, 5, 1])

# %%
model = keras.Sequential()

## The first layer need to have the input_shape
## set the number of neurons
model.add(layers.Dense(5, input_shape=(2,), activation='sigmoid'))

# output layer
model.add(layers.Dense(1, activation='sigmoid'))

# %%
## compiling and training
model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)
model.fit(X_train, y_train, epochs=25, validation_split=0.2, batch_size=32)
# Out:
# Epoch 1/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6309 - loss: 0.6670 - val_accuracy: 0.6325 - val_loss: 0.6644
# Epoch 2/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6510 - loss: 0.6621 - val_accuracy: 0.6363 - val_loss: 0.6591
# Epoch 3/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6531 - loss: 0.6571 - val_accuracy: 0.6388 - val_loss: 0.6535
# Epoch 4/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6560 - loss: 0.6516 - val_accuracy: 0.6413 - val_loss: 0.6475
# Epoch 5/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6563 - loss: 0.6456 - val_accuracy: 0.6413 - val_loss: 0.6409
# Epoch 6/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6565 - loss: 0.6389 - val_accuracy: 0.6363 - val_loss: 0.6337
# Epoch 7/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6554 - loss: 0.6316 - val_accuracy: 0.6325 - val_loss: 0.6259
# Epoch 8/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6493 - loss: 0.6236 - val_accuracy: 0.6313 - val_loss: 0.6175
# Epoch 9/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6487 - loss: 0.6152 - val_accuracy: 0.6463 - val_loss: 0.6088
# Epoch 10/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6704 - loss: 0.6065 - val_accuracy: 0.6737 - val_loss: 0.5997
# Epoch 11/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6975 - loss: 0.5977 - val_accuracy: 0.7237 - val_loss: 0.5905
# Epoch 12/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7360 - loss: 0.5888 - val_accuracy: 0.7588 - val_loss: 0.5812
# Epoch 13/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7574 - loss: 0.5800 - val_accuracy: 0.7800 - val_loss: 0.5720
# Epoch 14/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7742 - loss: 0.5712 - val_accuracy: 0.7900 - val_loss: 0.5628
# Epoch 15/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7865 - loss: 0.5626 - val_accuracy: 0.8050 - val_loss: 0.5537
# Epoch 16/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7965 - loss: 0.5542 - val_accuracy: 0.8150 - val_loss: 0.5448
# Epoch 17/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8039 - loss: 0.5460 - val_accuracy: 0.8225 - val_loss: 0.5361
# Epoch 18/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8089 - loss: 0.5379 - val_accuracy: 0.8288 - val_loss: 0.5276
# Epoch 19/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8160 - loss: 0.5301 - val_accuracy: 0.8325 - val_loss: 0.5193
# Epoch 20/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8206 - loss: 0.5225 - val_accuracy: 0.8413 - val_loss: 0.5112
# Epoch 21/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8277 - loss: 0.5152 - val_accuracy: 0.8475 - val_loss: 0.5033
# Epoch 22/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8327 - loss: 0.5080 - val_accuracy: 0.8550 - val_loss: 0.4957
# Epoch 23/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8358 - loss: 0.5011 - val_accuracy: 0.8562 - val_loss: 0.4883
# Epoch 24/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8447 - loss: 0.4944 - val_accuracy: 0.8612 - val_loss: 0.4811
# Epoch 25/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8474 - loss: 0.4879 - val_accuracy: 0.8675 - val_loss: 0.4741

# %%
results = model.evaluate(X_test, y_test, verbose=0)
print('Test Loss: {}'.format(results[0]))
print('Test Accuracy: {}'.format(results[1]))
plot_decision_boundary(lambda x: (
    model.predict(x) > 0.5).astype("int32"), X_test, y_test)
plt.title("1 Hidden layer NN, linear activation");
# Out:
# Test Loss: 0.48053091764450073
# Test Accuracy: 0.847000002861023
# 1288/1288 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step

# %% [markdown]
# ### Question 3:
# ####  What happens if we add one more hidden layer ?

# %%
draw_neural_net(.1, .9, .1, .9, [2, 3, 3, 1])

# %%
model = keras.Sequential()
# First hidden layer (need to innclude input_shape)
## Set the number of neurons
model.add(layers.Dense(3, input_shape=(2,), activation='sigmoid'))

# second hidden layer
## Complete the code
model.add(layers.Dense(3, activation='sigmoid'))

# output layer
model.add(layers.Dense(1, activation='sigmoid'))

# %%
## compiling and training
model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)
model.fit(X_train, y_train, epochs=25, validation_split=0.2, batch_size=32)
# Out:
# Epoch 1/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.4914 - loss: 0.6966 - val_accuracy: 0.4975 - val_loss: 0.6924
# Epoch 2/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5197 - loss: 0.6916 - val_accuracy: 0.5125 - val_loss: 0.6896
# Epoch 3/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5690 - loss: 0.6884 - val_accuracy: 0.5913 - val_loss: 0.6870
# Epoch 4/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6318 - loss: 0.6855 - val_accuracy: 0.5987 - val_loss: 0.6841
# Epoch 5/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6404 - loss: 0.6824 - val_accuracy: 0.5962 - val_loss: 0.6810
# Epoch 6/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6326 - loss: 0.6790 - val_accuracy: 0.5850 - val_loss: 0.6774
# Epoch 7/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6237 - loss: 0.6753 - val_accuracy: 0.5863 - val_loss: 0.6736
# Epoch 8/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6162 - loss: 0.6713 - val_accuracy: 0.5813 - val_loss: 0.6694
# Epoch 9/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6092 - loss: 0.6669 - val_accuracy: 0.5763 - val_loss: 0.6648
# Epoch 10/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6039 - loss: 0.6623 - val_accuracy: 0.5750 - val_loss: 0.6600
# Epoch 11/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6022 - loss: 0.6574 - val_accuracy: 0.5688 - val_loss: 0.6550
# Epoch 12/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5985 - loss: 0.6523 - val_accuracy: 0.5675 - val_loss: 0.6498
# Epoch 13/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5862 - loss: 0.6471 - val_accuracy: 0.5500 - val_loss: 0.6444
# Epoch 14/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5830 - loss: 0.6417 - val_accuracy: 0.5325 - val_loss: 0.6390
# Epoch 15/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5758 - loss: 0.6363 - val_accuracy: 0.5175 - val_loss: 0.6334
# Epoch 16/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5746 - loss: 0.6308 - val_accuracy: 0.5163 - val_loss: 0.6279
# Epoch 17/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5757 - loss: 0.6254 - val_accuracy: 0.5175 - val_loss: 0.6223
# Epoch 18/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5831 - loss: 0.6200 - val_accuracy: 0.5288 - val_loss: 0.6168
# Epoch 19/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5886 - loss: 0.6147 - val_accuracy: 0.6075 - val_loss: 0.6112
# Epoch 20/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6017 - loss: 0.6094 - val_accuracy: 0.6275 - val_loss: 0.6055
# Epoch 21/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6327 - loss: 0.6040 - val_accuracy: 0.6475 - val_loss: 0.5995
# Epoch 22/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6503 - loss: 0.5984 - val_accuracy: 0.6825 - val_loss: 0.5930
# Epoch 23/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6793 - loss: 0.5923 - val_accuracy: 0.7300 - val_loss: 0.5857
# Epoch 24/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7215 - loss: 0.5855 - val_accuracy: 0.7550 - val_loss: 0.5775
# Epoch 25/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7437 - loss: 0.5778 - val_accuracy: 0.7713 - val_loss: 0.5683

# %%
results = model.evaluate(X_test, y_test, verbose=0)
print('Test Loss: {}'.format(results[0]))
print('Test Accuracy: {}'.format(results[1]))
plot_decision_boundary(lambda x: (
    model.predict(x) > 0.5).astype("int32"), X_test, y_test)
plt.title("1 Hidden layer NN, linear activation");
# Out:
# Test Loss: 0.5711427330970764
# Test Accuracy: 0.7699999809265137
# 1288/1288 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step

# %% [markdown]
# ####  Use  the [hyperbolic tangent](https://mathworld.wolfram.com/HyperbolicTangent.html) activation `'tanh'` with the first simple model and compare the results with the sigmoid activation

# %%
model = keras.Sequential()
## The first layer need to have the input_shape
## change the activation function
model.add(layers.Dense(3, input_shape=(2,), activation='tanh'))
# output layer
model.add(layers.Dense(1, activation='sigmoid'))

# %%
## compiling and training
model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)
model.fit(X_train, y_train, epochs=25, validation_split=0.2, batch_size=32)
# Out:
# Epoch 1/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5044 - loss: 0.6888 - val_accuracy: 0.5888 - val_loss: 0.6739
# Epoch 2/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5840 - loss: 0.6761 - val_accuracy: 0.6450 - val_loss: 0.6642
# Epoch 3/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6590 - loss: 0.6643 - val_accuracy: 0.6938 - val_loss: 0.6566
# Epoch 4/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6839 - loss: 0.6545 - val_accuracy: 0.6687 - val_loss: 0.6482
# Epoch 5/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6670 - loss: 0.6437 - val_accuracy: 0.6575 - val_loss: 0.6317
# Epoch 6/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6593 - loss: 0.6258 - val_accuracy: 0.6488 - val_loss: 0.6099
# Epoch 7/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6560 - loss: 0.6060 - val_accuracy: 0.6488 - val_loss: 0.5903
# Epoch 8/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6630 - loss: 0.5877 - val_accuracy: 0.7550 - val_loss: 0.5709
# Epoch 9/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7713 - loss: 0.5696 - val_accuracy: 0.8250 - val_loss: 0.5518
# Epoch 10/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8127 - loss: 0.5520 - val_accuracy: 0.8487 - val_loss: 0.5335
# Epoch 11/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8297 - loss: 0.5351 - val_accuracy: 0.8662 - val_loss: 0.5160
# Epoch 12/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8483 - loss: 0.5191 - val_accuracy: 0.8813 - val_loss: 0.4995
# Epoch 13/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8572 - loss: 0.5039 - val_accuracy: 0.8838 - val_loss: 0.4839
# Epoch 14/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8667 - loss: 0.4896 - val_accuracy: 0.8888 - val_loss: 0.4693
# Epoch 15/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8727 - loss: 0.4761 - val_accuracy: 0.8975 - val_loss: 0.4555
# Epoch 16/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8787 - loss: 0.4635 - val_accuracy: 0.9050 - val_loss: 0.4426
# Epoch 17/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8890 - loss: 0.4517 - val_accuracy: 0.9087 - val_loss: 0.4306
# Epoch 18/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8924 - loss: 0.4406 - val_accuracy: 0.9112 - val_loss: 0.4192
# Epoch 19/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8981 - loss: 0.4301 - val_accuracy: 0.9200 - val_loss: 0.4086
# Epoch 20/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9008 - loss: 0.4204 - val_accuracy: 0.9250 - val_loss: 0.3987
# Epoch 21/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9074 - loss: 0.4112 - val_accuracy: 0.9262 - val_loss: 0.3893
# Epoch 22/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9074 - loss: 0.4026 - val_accuracy: 0.9312 - val_loss: 0.3805
# Epoch 23/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9107 - loss: 0.3945 - val_accuracy: 0.9312 - val_loss: 0.3723
# Epoch 24/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9123 - loss: 0.3869 - val_accuracy: 0.9325 - val_loss: 0.3645
# Epoch 25/25
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9131 - loss: 0.3797 - val_accuracy: 0.9337 - val_loss: 0.3572

# %%
results = model.evaluate(X_test, y_test, verbose=0)
print('Test Loss: {}'.format(results[0]))
print('Test Accuracy: {}'.format(results[1]))
plot_decision_boundary(lambda x: (
    model.predict(x) > 0.5).astype("int32"), X_test, y_test)
plt.title("1 Hidden layer NN, linear activation");
# Out:
# Test Loss: 0.3739857077598572
# Test Accuracy: 0.9120000004768372
# 1288/1288 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step

# %% [markdown]
# ## Practice I
#
# Repeat the process with a different dataset.

# %%
N = 5000
X, y = sklearn.datasets.make_moons(n_samples=N, noise=.18)

# %%
# Visualize the data:
plt.scatter(X[:,0], X[:,1], c=y.ravel(), s=40, cmap=plt.cm.Spectral);

# %%
# train test split
from sklearn.model_selection import train_test_split

(X_train, X_test, y_train, y_test) = train_test_split(
    X,
    y,
    test_size=0.25,
)
print('X shape:{0}, y shape:{1}'.format(X.shape, y.shape))
print('X_train shape:{0}, y_train shape:{1}'.format(X_train.shape,
                                                    y_train.shape))
print('X_test shape:{0}, y_test shape:{1}'.format(X_test.shape, y_test.shape))
# Out:
# X shape:(5000, 2), y shape:(5000,)
# X_train shape:(3750, 2), y_train shape:(3750,)
# X_test shape:(1250, 2), y_test shape:(1250,)

# %% [markdown]
# ### Define your model

# %%
model = keras.Sequential()
## The first layer need to have the input_shape
model.add(layers.Dense(8, input_shape=(2,), activation='tanh'))

## Second Layer, don't use input_shape
model.add(layers.Dense(8, activation='tanh'))

# output layer
model.add(layers.Dense(1, activation='sigmoid'))

# %%
## compiling and training
model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)
model.fit(X_train, y_train, epochs=35, validation_split=0.2, batch_size=64)
# Out:
# Epoch 1/35
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.3488 - loss: 0.7604 - val_accuracy: 0.8013 - val_loss: 0.6031
# Epoch 2/35
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8451 - loss: 0.5659 - val_accuracy: 0.8587 - val_loss: 0.4711
# Epoch 3/35
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8696 - loss: 0.4439 - val_accuracy: 0.8627 - val_loss: 0.3875
# Epoch 4/35
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8741 - loss: 0.3686 - val_accuracy: 0.8600 - val_loss: 0.3416
# Epoch 5/35
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8752 - loss: 0.3277 - val_accuracy: 0.8627 - val_loss: 0.3179
# Epoch 6/35
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8792 - loss: 0.3065 - val_accuracy: 0.8667 - val_loss: 0.3055
# Epoch 7/35
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8825 - loss: 0.2952 - val_accuracy: 0.8667 - val_loss: 0.2988
# Epoch 8/35
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8826 - loss: 0.2890 - val_accuracy: 0.8640 - val_loss: 0.2949
# Epoch 9/35
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8825 - loss: 0.2855 - val_accuracy: 0.8640 - val_loss: 0.2927
# Epoch 10/35
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8822 - loss: 0.2834 - val_accuracy: 0.8653 - val_loss: 0.2913
# Epoch 11/35
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8822 - loss: 0.2820 - val_accuracy: 0.8653 - val_loss: 0.2904
# Epoch 12/35
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8822 - loss: 0.2811 - val_accuracy: 0.8653 - val_loss: 0.2897
# Epoch 13/35
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8823 - loss: 0.2804 - val_accuracy: 0.8640 - val_loss: 0.2891
# Epoch 14/35
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8823 - loss: 0.2799 - val_accuracy: 0.8640 - val_loss: 0.2887
# Epoch 15/35
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8825 - loss: 0.2794 - val_accuracy: 0.8640 - val_loss: 0.2882
# Epoch 16/35
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8833 - loss: 0.2790 - val_accuracy: 0.8640 - val_loss: 0.2878
# Epoch 17/35
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8830 - loss: 0.2786 - val_accuracy: 0.8640 - val_loss: 0.2874
# Epoch 18/35
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8831 - loss: 0.2783 - val_accuracy: 0.8640 - val_loss: 0.2871
# Epoch 19/35
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8831 - loss: 0.2780 - val_accuracy: 0.8640 - val_loss: 0.2867
# Epoch 20/35
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8831 - loss: 0.2777 - val_accuracy: 0.8640 - val_loss: 0.2864
# Epoch 21/35
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8831 - loss: 0.2774 - val_accuracy: 0.8640 - val_loss: 0.2861
# Epoch 22/35
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8834 - loss: 0.2771 - val_accuracy: 0.8640 - val_loss: 0.2858
# Epoch 23/35
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8834 - loss: 0.2768 - val_accuracy: 0.8653 - val_loss: 0.2856
# Epoch 24/35
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8834 - loss: 0.2766 - val_accuracy: 0.8653 - val_loss: 0.2853
# Epoch 25/35
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8834 - loss: 0.2764 - val_accuracy: 0.8653 - val_loss: 0.2850
# Epoch 26/35
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8826 - loss: 0.2761 - val_accuracy: 0.8653 - val_loss: 0.2848
# Epoch 27/35
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8826 - loss: 0.2759 - val_accuracy: 0.8653 - val_loss: 0.2846
# Epoch 28/35
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8826 - loss: 0.2757 - val_accuracy: 0.8653 - val_loss: 0.2844
# Epoch 29/35
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8826 - loss: 0.2755 - val_accuracy: 0.8653 - val_loss: 0.2842
# Epoch 30/35
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8826 - loss: 0.2754 - val_accuracy: 0.8653 - val_loss: 0.2840
# Epoch 31/35
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8826 - loss: 0.2752 - val_accuracy: 0.8653 - val_loss: 0.2838
# Epoch 32/35
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8829 - loss: 0.2750 - val_accuracy: 0.8653 - val_loss: 0.2836
# Epoch 33/35
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8829 - loss: 0.2749 - val_accuracy: 0.8653 - val_loss: 0.2834
# Epoch 34/35
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8829 - loss: 0.2747 - val_accuracy: 0.8653 - val_loss: 0.2833
# Epoch 35/35
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8829 - loss: 0.2746 - val_accuracy: 0.8653 - val_loss: 0.2831

# %%
results = model.evaluate(X_test, y_test, verbose=0)
print('Test Loss: {}'.format(results[0]))
print('Test Accuracy: {}'.format(results[1]))
plot_decision_boundary(lambda x: (
    model.predict(x) > 0.5).astype("int32"), X_test, y_test)
# Out:
# Test Loss: 0.3024888336658478
# Test Accuracy: 0.8592000007629395
# 336/336 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step

# %% [markdown]
# ## Saving and Loading Keras Models
#
# You can easily save your entire model (architecture, weights, and optimizer state) in a single call using either `.keras` or `.h5` formats.
#
# - **`.keras`**: The default and recommended format from TensorFlow 2.12 onwards. It includes comprehensive model metadata and is future-proof.
# - **`.h5`**: An older HDF5 format that is still widely used due to its simplicity and compatibility.

# %%
import datetime

# Save model with timestamp
current_time = datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
model_name_keras = f"keras_model_{current_time}.keras"
model_name_h5 = f"keras_model_{current_time}.h5"

# Save in .keras format (recommended for TensorFlow/Keras > 2.12)
model.save(model_name_keras)

# Alternatively, save in .h5 format
model.save(model_name_h5)

print(f"Models saved as: {model_name_keras} and {model_name_h5}")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Models saved as: keras_model_20250606-084249.keras and keras_model_20250606-084249.h5

# %%
# List files in current directory
# !ls -l

# %%
from tensorflow.keras.models import load_model

# Load your previously saved model
loaded_model = load_model(model_name_keras)  # or .h5

# Evaluate loaded model
loss, accuracy = loaded_model.evaluate(X_test, y_test)
print(f"Loaded model accuracy: {accuracy*100:.2f}%")

# %% [markdown]
# ### Question 4: Train 10 epochs, save the model, load it, and then train 10 more epochs

# %%
model = keras.Sequential()
## The first layer need to have the input_shape
model.add(layers...(..., input_shape=(...,), activation=...))

## Second Layer, don't use input_shape
model...(...)

# output layer
model.add(layers.Dense(..., activation=...))

# %%
## compiling and training
model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)
model.fit(X_train, y_train, epochs=..., validation_split=0.2, batch_size=64)

# %%
# Save the model
model_name = ...
model.save(...

# %%
# load the model

# %%
# Train the model 10 more epochs
model.fit(X_train, y_train, epochs=..., validation_split=0.2, batch_size=64)

# %% [markdown]
# ## Functional API
#
# The Keras Functional API allows defining the topology of the models as a [acyclic directed graph](https://en.wikipedia.org/wiki/Directed_acyclic_graph) of layers. Next we will build the same model as in the previous section but using the Keras Functional API.
#
# You need to start with an input data entry:
# ```python
#     inputs = keras.Input(shape=(8,))
# ```
#
# We define the layers that we will include in the network and the relationships between them. It is important to note that each line details the type of layer and its properties (number of neurons, activation function, name ...) and just at the end, in parentheses, the name of the variable in which we have saved the layer from which its output will connect to the input of the layer we are declaring.
# ```python
# layer_1 = layers.Dense(4, activation='sigmoid',
#                        name='layer_1')(inputs)
# layer_2 = layers.Dense(4, activation='sigmoid',
#                        name='layer_2')(layer_1)
# ```
#
# The "layer call" `Dense()(inputs)` action is like drawing an arrow from "inputs" to this layer you created. You're "passing" the inputs to the dense layer, and you get `layer_1` as the output.
#
#
#
# Finally, we define the network outputs:
# ```python
# outputs = layers.Dense(1, name='output_layer')(layer_2)
# ```
#
# We create the model specifying the inputs and outputs:
# ```python
# model = keras.Model(inputs=inputs, outputs=outputs)
# ```

# %%
draw_neural_net(.1, .9, .1, .9, [8, 4, 4, 1])

# %%
inputs = keras.Input(shape=(8, ), name='input_layer')
l_1 = layers.Dense(4, activation='relu', name='layer_1')(inputs)
l_2 = layers.Dense(4, activation='relu', name='layer_2')(l_1)
outputs = layers.Dense(1, activation="sigmoid", name='output_layer')(l_2)

model = keras.Model(inputs=inputs, outputs=outputs, name='example_model')

model.summary()
# Out:
# Model: "example_model"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 8)              │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ layer_1 (Dense)                 │ (None, 4)              │            36 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ layer_2 (Dense)                 │ (None, 4)              │            20 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ output_layer (Dense)            │ (None, 1)              │             5 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 61 (244.00 B)
#  Trainable params: 61 (244.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
plot_model(model, show_shapes=True)

# %% [markdown]
# ## Practice II
#
# Repeat the process with a different dataset and the **Functional API**

# %%
N = 5000
X, y = sklearn.datasets.make_circles(n_samples=N, factor=.65, noise=.065) # sklearn.datasets.make_moons(n_samples=N, noise=.15)

# %%
# Visualize the data:
plt.scatter(X[:,0], X[:,1], c=y.ravel(), s=40, cmap=plt.cm.Spectral);

# %%
# train test split
from sklearn.model_selection import train_test_split

(X_train, X_test, y_train, y_test) = train_test_split(
    X,
    y,
    test_size=0.25,
)
print('X shape:{0}, y shape:{1}'.format(X.shape, y.shape))
print('X_train shape:{0}, y_train shape:{1}'.format(X_train.shape,
                                                    y_train.shape))
print('X_test shape:{0}, y_test shape:{1}'.format(X_test.shape, y_test.shape))
# Out:
# X shape:(5000, 2), y shape:(5000,)
# X_train shape:(3750, 2), y_train shape:(3750,)
# X_test shape:(1250, 2), y_test shape:(1250,)

# %% [markdown]
# ### Define your model

# %%
inputs = keras.Input(shape=(2, ), name='input_layer')
## First hidden layer
l_1 = layers.Dense(8, activation='tanh', name='layer_1')(inputs)
l_2 = layers.Dense(8, activation='tanh', name='layer_2')(l_1)

## output layer
outputs = layers.Dense(1, activation='sigmoid')(l_2)


model = keras.Model(inputs=inputs, outputs = outputs)

# %%
## compiling and training
model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)
model.fit(X_train, y_train, epochs=35, validation_split=0.2, batch_size=64)
# Out:
# Epoch 1/35
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.4890 - loss: 0.7049 - val_accuracy: 0.5427 - val_loss: 0.6918
# Epoch 2/35
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5540 - loss: 0.6931 - val_accuracy: 0.5440 - val_loss: 0.6910
# Epoch 3/35
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5500 - loss: 0.6901 - val_accuracy: 0.5587 - val_loss: 0.6898
# Epoch 4/35
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5673 - loss: 0.6883 - val_accuracy: 0.5480 - val_loss: 0.6882
# Epoch 5/35
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.5737 - loss: 0.6864 - val_accuracy: 0.5560 - val_loss: 0.6860
# Epoch 6/35
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5854 - loss: 0.6840 - val_accuracy: 0.5693 - val_loss: 0.6832
# Epoch 7/35
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5901 - loss: 0.6810 - val_accuracy: 0.5747 - val_loss: 0.6796
# Epoch 8/35
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5984 - loss: 0.6773 - val_accuracy: 0.6013 - val_loss: 0.6752
# Epoch 9/35
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6256 - loss: 0.6727 - val_accuracy: 0.6613 - val_loss: 0.6699
# Epoch 10/35
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6836 - loss: 0.6673 - val_accuracy: 0.6987 - val_loss: 0.6639
# Epoch 11/35
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7189 - loss: 0.6611 - val_accuracy: 0.7080 - val_loss: 0.6569
# Epoch 12/35
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7383 - loss: 0.6539 - val_accuracy: 0.7280 - val_loss: 0.6491
# Epoch 13/35
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7480 - loss: 0.6458 - val_accuracy: 0.7373 - val_loss: 0.6403
# Epoch 14/35
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7608 - loss: 0.6366 - val_accuracy: 0.7480 - val_loss: 0.6304
# Epoch 15/35
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7705 - loss: 0.6262 - val_accuracy: 0.7573 - val_loss: 0.6191
# Epoch 16/35
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7822 - loss: 0.6143 - val_accuracy: 0.7760 - val_loss: 0.6063
# Epoch 17/35
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7949 - loss: 0.6007 - val_accuracy: 0.8013 - val_loss: 0.5916
# Epoch 18/35
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8102 - loss: 0.5853 - val_accuracy: 0.8360 - val_loss: 0.5750
# Epoch 19/35
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8374 - loss: 0.5679 - val_accuracy: 0.8600 - val_loss: 0.5562
# Epoch 20/35
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8672 - loss: 0.5483 - val_accuracy: 0.8920 - val_loss: 0.5353
# Epoch 21/35
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9004 - loss: 0.5267 - val_accuracy: 0.9293 - val_loss: 0.5124
# Epoch 22/35
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9373 - loss: 0.5033 - val_accuracy: 0.9587 - val_loss: 0.4880
# Epoch 23/35
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9724 - loss: 0.4786 - val_accuracy: 0.9773 - val_loss: 0.4626
# Epoch 24/35
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9801 - loss: 0.4532 - val_accuracy: 0.9853 - val_loss: 0.4367
# Epoch 25/35
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9883 - loss: 0.4275 - val_accuracy: 0.9867 - val_loss: 0.4110
# Epoch 26/35
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9888 - loss: 0.4021 - val_accuracy: 0.9907 - val_loss: 0.3859
# Epoch 27/35
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9908 - loss: 0.3774 - val_accuracy: 0.9907 - val_loss: 0.3617
# Epoch 28/35
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9913 - loss: 0.3536 - val_accuracy: 0.9933 - val_loss: 0.3387
# Epoch 29/35
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9914 - loss: 0.3310 - val_accuracy: 0.9933 - val_loss: 0.3168
# Epoch 30/35
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9918 - loss: 0.3096 - val_accuracy: 0.9920 - val_loss: 0.2963
# Epoch 31/35
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9918 - loss: 0.2895 - val_accuracy: 0.9920 - val_loss: 0.2770
# Epoch 32/35
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9924 - loss: 0.2706 - val_accuracy: 0.9907 - val_loss: 0.2591
# Epoch 33/35
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9934 - loss: 0.2530 - val_accuracy: 0.9920 - val_loss: 0.2424
# Epoch 34/35
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9934 - loss: 0.2366 - val_accuracy: 0.9960 - val_loss: 0.2269
# Epoch 35/35
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9935 - loss: 0.2214 - val_accuracy: 0.9960 - val_loss: 0.2125

# %%
results = model.evaluate(X_test, y_test, verbose=0)
print('Test Loss: {}'.format(results[0]))
print('Test Accuracy: {}'.format(results[1]))
plot_decision_boundary(lambda x: (
    model.predict(x) > 0.5).astype("int32"), X_test, y_test)
# Out:
# Test Loss: 0.2112884521484375
# Test Accuracy: 0.995199978351593
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step

# %% [markdown]
# ## Visualize decision boundary by epoch

# %%
from sklearn.preprocessing import StandardScaler
from IPython.display import Image
import os

# %%
def plot_save_decision_boundary(model, X, y, epoch, epoch_image):
    h = 0.1
    x_min, x_max = X[:, 0].min() - 1, X[:, 0].max() + 1
    y_min, y_max = X[:, 1].min() - 1, X[:, 1].max() + 1
    xx, yy = np.meshgrid(np.arange(x_min, x_max, h),
                         np.arange(y_min, y_max, h))

    X_grid = np.c_[xx.ravel(), yy.ravel()]
    Z = model.predict(X_grid)
    Z = Z.reshape(xx.shape)

    plt.contourf(xx, yy, Z, alpha=0.5, colors=['blue', 'red'], levels=[-0.5, 0.5, 1.5])
    plt.scatter(X[y[:, 0] == 0][:, 0], X[y[:, 0] == 0][:, 1], color='blue', label='Class 0', alpha=0.5)
    plt.scatter(X[y[:, 0] == 1][:, 0], X[y[:, 0] == 1][:, 1], color='red', label='Class 1', alpha=0.5)
    plt.title(f'Epoch {epoch}')
    plt.savefig(epoch_image)
    plt.close()

def generate_spiral_dataset(n_points, noise=0.5):
    n = np.sqrt(np.random.rand(n_points, 1)) * 780 * (2 * np.pi) / 360
    d1x = -np.cos(n) * n + np.random.rand(n_points, 1) * noise
    d1y = np.sin(n) * n + np.random.rand(n_points, 1) * noise

    X, y = (np.vstack((np.hstack((d1x, d1y)), np.hstack((-d1x, -d1y)))),
            np.hstack((np.zeros(n_points), np.ones(n_points))))
    return X, y.reshape(-1, 1)

n_points = 2500
X, y = generate_spiral_dataset(n_points)

# %%
plt.scatter(X[y[:, 0] == 0][:, 0], X[y[:, 0] == 0][:, 1], color='blue', label='Class 0')
plt.scatter(X[y[:, 0] == 1][:, 0], X[y[:, 0] == 1][:, 1], color='red', label='Class 1')
plt.legend()
plt.show()

# %%
# Normalize data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Dense(16, activation='relu', input_shape=(2,)),
    tf.keras.layers.Dense(1, activation='sigmoid')
])

model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.01),
              loss='binary_crossentropy',
              metrics=['accuracy'])

n_epochs = 60
epoch_images = []

for epoch in range(n_epochs):
    model.fit(X_train, y_train, epochs=1, verbose=0)
    epoch_image = f'epoch_{epoch}.png'
    epoch_images.append(epoch_image)

    plot_save_decision_boundary(model, X_test, y_test, epoch, epoch_image)

# %%
from PIL import Image as Image_PIL

# Create the GIF
gif_filename = 'epoch_animation.gif'
images = [Image_PIL.open(epoch_image) for epoch_image in epoch_images]

duration = 0.15
images[0].save(gif_filename,
            format='GIF',
            append_images=images[1:],
            save_all=True,
            duration=duration*1000,
            loop=0)

# Delete the individual epoch images
for epoch_image in epoch_images:
    os.remove(epoch_image)

# %%
# Display the GIF
Image(filename=gif_filename)
